# %%
import pandas as pd
import numpy as np

album_file = "./data/spotify_spotify_albums.csv"
album = pd.read_csv(album_file, header=0, sep=',', lineterminator='\n')

artists_file = "./data/spotify_spotify_artists.csv"
artists = pd.read_csv(artists_file, header=0)

track_file = "./data/spotify_spotify_tracks.csv"
tracks = pd.read_csv(track_file, header=0)

#prints the first 5 rows of the corresponding files
print(f"The first 5 rows of the album file:\n{album.head()}\n")
print(f"The first 5 rows of the artists file:\n{artists.head()}\n")
print(f"The first 5 rows of the tracks file:\n{tracks.head()}\n")
# Out:
# The first 5 rows of the album file:
#    Unnamed: 0 album_type               artist_id  \
# 0           0     single  3DiDSECUqqY1AuBP8qtaIa
# 1           1      album  6s1pCNXcbdtQJlsnM1hRIA
# 2           2     single  5YjfNaHq05WrwldRe1QSBc
# 3           3     single  2G9Vc16JCpnZmK4uGH46Fa
# 4           4     single  2dwM9OcE4c3Ph1UBINSodx
#
#                                    available_markets  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 1  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 2  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 3  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 4  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/1g...
# 1  {'spotify': 'https://open.spotify.com/album/4K...
# 2  {'spotify': 'https://open.spotify.com/album/7n...
# 3  {'spotify': 'https://open.spotify.com/album/6p...
# 4  {'spotify': 'https://open.spotify.com/album/1X...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/1gAM7M4rBwEb...  1gAM7M4rBwEbSPeAQR2nx1
# 1  https://api.spotify.com/v1/albums/4KfJZV7WfolY...  4KfJZV7WfolYlxBzOTo66s
# 2  https://api.spotify.com/v1/albums/7nLYY7uAVUb5...  7nLYY7uAVUb57kpd7tZxnS
# 3  https://api.spotify.com/v1/albums/6p20Rt4x2Qn5...  6p20Rt4x2Qn5mUMRi1s6pj
# 4  https://api.spotify.com/v1/albums/1XeoOqC1q7U2...  1XeoOqC1q7U2iyLEQJ64cu
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                                 name release_date  \
# 0                              If I Ain't Got You EP   2019-02-08
# 1  Shostakovich Symphony No.5 - Four Romances on ...   2019-03-01
# 2                                       Take My Bass   2019-03-14
# 3                                Hypnotizing (Are U)   2016-11-16
# 4                                           Sunshine   2018-07-20
#
#   release_date_precision  total_tracks                track_id  \
# 0                    day             6  2iejTMy9XZ8Gaae0aQ2yl0
# 1                    day             8  1WQfghEjszJJ4H8MAWrQ2C
# 2                    day             1  3jJKj4QTK3v18ZSwpk7AcV
# 3                    day             1  1xGtDafUZbHyYC3Xarcbrj
# 4                    day             1  0gWtsXvXOzAT6FtM3ur8in
#
#   track_name_prev                                   uri   type\r
# 0        track_32  spotify:album:1gAM7M4rBwEbSPeAQR2nx1  album\r
# 1        track_11  spotify:album:4KfJZV7WfolYlxBzOTo66s  album\r
# 2        track_15  spotify:album:7nLYY7uAVUb57kpd7tZxnS  album\r
# 3        track_46  spotify:album:6p20Rt4x2Qn5mUMRi1s6pj  album\r
# 4        track_10  spotify:album:1XeoOqC1q7U2iyLEQJ64cu  album\r
#
# The first 5 rows of the artists file:
#    Unnamed: 0  artist_popularity  followers  \
# 0           0                 44      23230
# 1           1                 22        313
# 2           2                 26       1596
# 3           3                 31        149
# 4           4                 21         11
#
#                                               genres                      id  \
# 0  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 1                                                 []  1dLnVku4VQUOLswwDFvRc9
# 2                                ['danish pop rock']  6YVY310fjfUzKi8hiqR7iK
# 3                             ['uk alternative pop']  2VElyouiCfoYPDJluzwJwK
# 4                                 ['french baroque']  4agVy03qW8juSysCTUOuDI
#
#                   name                track_id track_name_prev    type
# 0        Juliano Cezar  0wmDmAILuW9e2aRttkl4aC         track_9  artist
# 1       The Grenadines  4wqwj0gA8qPZKLl5WVqXml        track_30  artist
# 2              Gangway  1bFqWDbvHmZe2f4Nf9qaD8        track_38  artist
# 3                FADES  3MFSUBAidPzRBbIS7BDj1S        track_34  artist
# 4  Jean-Pierre Guignon  2r3q57FhxdsCyYr0kuDq4b        track_26  artist
#
# The first 5 rows of the tracks file:
#    Unnamed: 0  acousticness                album_id  \
# 0           0         0.294  0D3QufeCudpQANOR7luqdr
# 1           1         0.863  1bcqsH5UyTBzmh9YizdsBE
# 2           2         0.750  4tKijjmxGClg4JOLAyo2qE
# 3           3         0.763  6FeJF5r8roonnKraJxr4oB
# 4           4         0.770  4tKijjmxGClg4JOLAyo2qE
#
#                                         analysis_url  \
# 0  https://api.spotify.com/v1/audio-analysis/5qlj...
# 1  https://api.spotify.com/v1/audio-analysis/3VAX...
# 2  https://api.spotify.com/v1/audio-analysis/1L3Y...
# 3  https://api.spotify.com/v1/audio-analysis/6aCe...
# 4  https://api.spotify.com/v1/audio-analysis/1Vo8...
#
#                    artists_id  \
# 0  ['3mxJuHRn2ZWD5OofvJtDZY']
# 1  ['4xWMewm6CYMstu0sPgd9jJ']
# 2  ['3hYaK5FF3YAglCj5HZgBnP']
# 3  ['2KQsUB9DRBcJk17JWX1eXD']
# 4  ['3hYaK5FF3YAglCj5HZgBnP']
#
#                                    available_markets country  danceability  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.698
# 1  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.719
# 2                                             ['GB']      BE         0.466
# 3  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.719
# 4                                             ['GB']      BE         0.460
#
#    disc_number  duration_ms  ...  \
# 0          1.0     235584.0  ...
# 1          1.0     656960.0  ...
# 2          1.0     492840.0  ...
# 3          1.0     316578.0  ...
# 4          1.0     558880.0  ...
#
#                                          preview_url speechiness    tempo  \
# 0  https://p.scdn.co/mp3-preview/1b05a902da3a251d...      0.0262  115.018
# 1  https://p.scdn.co/mp3-preview/d8140736a6131cb5...      0.9220  115.075
# 2  https://p.scdn.co/mp3-preview/c8af28fb15185b18...      0.9440   79.565
# 3  https://p.scdn.co/mp3-preview/7629b8e9f31f6e9b...      0.9380  112.822
# 4  https://p.scdn.co/mp3-preview/32be593c0eb82868...      0.9430   81.260
#
#    time_signature                                         track_href  \
# 0             4.0  https://api.spotify.com/v1/tracks/5qljLQuKnNJf...
# 1             3.0  https://api.spotify.com/v1/tracks/3VAX2MJdmdqA...
# 2             4.0  https://api.spotify.com/v1/tracks/1L3YAhsEMrGV...
# 3             3.0  https://api.spotify.com/v1/tracks/6aCe9zzoZmCo...
# 4             4.0  https://api.spotify.com/v1/tracks/1Vo802A38tPF...
#
#    track_name_prev  track_number                                   uri  \
# 0         track_14           1.0  spotify:track:5qljLQuKnNJf4F4vfxQB0V
# 1          track_3           3.0  spotify:track:3VAX2MJdmdqARLSU5hPMpm
# 2          track_4           4.0  spotify:track:1L3YAhsEMrGVvCgDXj2TYn
# 3          track_9           1.0  spotify:track:6aCe9zzoZmCojX7bbgKKtf
# 4          track_2           2.0  spotify:track:1Vo802A38tPFHmje1h91um
#
#    valence   type
# 0   0.6220  track
# 1   0.5890  track
# 2   0.0850  track
# 3   0.5330  track
# 4   0.0906  track
#
# [5 rows x 32 columns]

# %%
#prints the last 5 rows of the corresponding files
print(f"The last 5 rows of the album file:\n{album.tail()}\n")
print(f"The last 5 rows of the artists file:\n{artists.tail()}\n")
print(f"The last 5 rows of the tracks file:\n{tracks.tail()}\n")
# Out:
# The last 5 rows of the album file:
#        Unnamed: 0 album_type               artist_id  \
# 75506       75506      album  0S7CCsKpXJ8e1dIstizHw5
# 75507       75507      album  73Vk4dL8kYkbRJxWJDq1wL
# 75508       75508      album  3yW6jTzGjHUUkLvLkjLOVn
# 75509       75509      album  4iudEcmuPlYNdbP3e1bdn1
# 75510       75510      album  023YMawCG3OvACmRjWxLWC
#
#                                        available_markets  \
# 75506  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 75507  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 75508                                       ['AU', 'NZ']
# 75509  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 75510  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
#
#                                            external_urls  \
# 75506  {'spotify': 'https://open.spotify.com/album/4Z...
# 75507  {'spotify': 'https://open.spotify.com/album/4D...
# 75508  {'spotify': 'https://open.spotify.com/album/4P...
# 75509  {'spotify': 'https://open.spotify.com/album/51...
# 75510  {'spotify': 'https://open.spotify.com/album/7H...
#
#                                                     href  \
# 75506  https://api.spotify.com/v1/albums/4ZbkQn6amf1t...
# 75507  https://api.spotify.com/v1/albums/4DifRQy4Dyey...
# 75508  https://api.spotify.com/v1/albums/4PXy3cBCNeY0...
# 75509  https://api.spotify.com/v1/albums/511p6iaCuK8S...
# 75510  https://api.spotify.com/v1/albums/7H3Bgvb3hs4v...
#
#                            id  \
# 75506  4ZbkQn6amf1t3a202zen2u
# 75507  4DifRQy4Dyey9NSS7ywnEx
# 75508  4PXy3cBCNeY0ZVKTOGi9Cw
# 75509  511p6iaCuK8Sr0BYdpcfkq
# 75510  7H3Bgvb3hs4vvLwccHDRlr
#
#                                                   images  \
# 75506  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 75507  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 75508  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 75509  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 75510  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                               name release_date release_date_precision  \
# 75506              Latino For Life   2014-01-24                    day
# 75507                Dime Qué Pasa   2011-03-31                    day
# 75508  Black Fingernails, Red Wine   2006-06-10                    day
# 75509                   Freak Show         1997                   year
# 75510               The Cat Empire   2003-10-24                    day
#
#        total_tracks                track_id track_name_prev  \
# 75506            13  3CZY7jD1Zf30zIdbwS5212        track_17
# 75507            11  7GOBsKucPG5Bh8qzStmrQ6        track_18
# 75508            13  0ujklxrVM2jwpLMgbTwTd1         track_7
# 75509            13  58nHFSWj5N5JxNtWgS85TL        track_14
# 75510            13  1pXtUVmSS3Aky3j6nQ4sQT        track_21
#
#                                         uri   type\r
# 75506  spotify:album:4ZbkQn6amf1t3a202zen2u  album\r
# 75507  spotify:album:4DifRQy4Dyey9NSS7ywnEx  album\r
# 75508  spotify:album:4PXy3cBCNeY0ZVKTOGi9Cw  album\r
# 75509  spotify:album:511p6iaCuK8Sr0BYdpcfkq  album\r
# 75510  spotify:album:7H3Bgvb3hs4vvLwccHDRlr  album\r
#
# The last 5 rows of the artists file:
#        Unnamed: 0  artist_popularity  followers  \
# 56124       56124                 23       1212
# 56125       56125                 42      57973
# 56126       56126                 38      20870
# 56127       56127                 44      33923
# 56128       56128                 44      42026
#
#                                                   genres  \
# 56124                                   ['chilean rock']
# 56125  ['aggro chileno', 'andean', 'chilean rock', 'l...
# 56126  ['australian alternative rock', 'australian ro...
# 56127  ['australian alternative rock', 'australian ro...
# 56128  ['australian alternative rock', 'australian in...
#
#                            id                   name                track_id  \
# 56124  48YkQQTWzmT248VY8DF7Fv  Profetas y Freneticos  29WK73lMQpLELfHd6PfbjY
# 56125  1OgaghfYd1qr8DFoNrfDNk               Sinergia  0rXhmIYRPIoVYstJdZt4uq
# 56126  7o9kdTx6RmO12iAVVsNehd         The Superjesus  1B7tV3WzEnDUS7wXSKDXk3
# 56127  6n3YUZcayLRuAunJUUelvz           Regurgitator  4e5wI6VC4eVDTtpyZ409Pw
# 56128  47yawJswuSfSvizYhItoOP     Something For Kate  1bOjAQHYtPIsZfPAc1Qq61
#
#       track_name_prev    type
# 56124        track_20  artist
# 56125        track_21  artist
# 56126         track_1  artist
# 56127         track_8  artist
# 56128         track_9  artist
#
# The last 5 rows of the tracks file:
#         Unnamed: 0  acousticness                album_id  \
# 101934      101934      0.005640  1M9n4vCmOH4lbcHrpt21Qy
# 101935      101935      0.000406  511p6iaCuK8Sr0BYdpcfkq
# 101936      101936      0.004510  511p6iaCuK8Sr0BYdpcfkq
# 101937      101937      0.333000  7H3Bgvb3hs4vvLwccHDRlr
# 101938      101938      0.028400  3oieBBYbUOve0VpxTCpHr1
#
#                                              analysis_url  \
# 101934  https://api.spotify.com/v1/audio-analysis/4e5w...
# 101935  https://api.spotify.com/v1/audio-analysis/58nH...
# 101936  https://api.spotify.com/v1/audio-analysis/2RDg...
# 101937  https://api.spotify.com/v1/audio-analysis/1pXt...
# 101938  https://api.spotify.com/v1/audio-analysis/6MzG...
#
#                         artists_id  \
# 101934  ['6n3YUZcayLRuAunJUUelvz']
# 101935  ['4iudEcmuPlYNdbP3e1bdn1']
# 101936  ['4iudEcmuPlYNdbP3e1bdn1']
# 101937  ['023YMawCG3OvACmRjWxLWC']
# 101938  ['6OgAO7QYncP5feMijPxBxi']
#
#                                         available_markets country  \
# 101934                                       ['AU', 'NZ']      AR
# 101935  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      AR
# 101936  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      AR
# 101937  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      AR
# 101938  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      AR
#
#         danceability  disc_number  duration_ms  ...  \
# 101934         0.602          1.0     178893.0  ...
# 101935         0.177          1.0     213133.0  ...
# 101936         0.539          1.0     226107.0  ...
# 101937         0.716          1.0     224133.0  ...
# 101938         0.500          1.0     251787.0  ...
#
#                                               preview_url speechiness  \
# 101934  https://p.scdn.co/mp3-preview/06f1c1e06ce801d5...      0.0327
# 101935  https://p.scdn.co/mp3-preview/c5a00b395106508f...      0.0604
# 101936  https://p.scdn.co/mp3-preview/128c860edbac0c6e...      0.0653
# 101937  https://p.scdn.co/mp3-preview/447bbc0bf9324173...      0.1510
# 101938  https://p.scdn.co/mp3-preview/c3d9e399a329d25d...      0.0324
#
#           tempo  time_signature  \
# 101934  130.186             4.0
# 101935  184.260             4.0
# 101936  118.043             4.0
# 101937  110.015             4.0
# 101938  139.749             4.0
#
#                                                track_href  track_name_prev  \
# 101934  https://api.spotify.com/v1/tracks/4e5wI6VC4eVD...         track_10
# 101935  https://api.spotify.com/v1/tracks/58nHFSWj5N5J...         track_16
# 101936  https://api.spotify.com/v1/tracks/2RDgs05sg2vr...         track_21
# 101937  https://api.spotify.com/v1/tracks/1pXtUVmSS3Ak...         track_26
# 101938  https://api.spotify.com/v1/tracks/6MzG4xUhUHNL...         track_30
#
#         track_number                                   uri  valence   type
# 101934           4.0  spotify:track:4e5wI6VC4eVDTtpyZ409Pw    0.787  track
# 101935           7.0  spotify:track:58nHFSWj5N5JxNtWgS85TL    0.363  track
# 101936           2.0  spotify:track:2RDgs05sg2vrpwiAEUkWd0    0.406  track
# 101937           5.0  spotify:track:1pXtUVmSS3Aky3j6nQ4sQT    0.760  track
# 101938           9.0  spotify:track:6MzG4xUhUHNLZBe3RAC2cX    0.641  track
#
# [5 rows x 32 columns]

# %%
#.shape returns a tuple where the first value is the number of rows and the second value is the number of columns
print(album.shape)
print(artists.shape)
print(tracks.shape)
# Out:
# (75511, 16)
# (56129, 9)
# (101939, 32)

# %%
#displays only the rows 10-20 of the 'name' and 'release date' column
album.iloc[10:21][['name', 'release_date']]
# Out:
#                                                  name release_date
# 10  Beethoven: 6 Bagatelles & Piano Sonatas Nos. 3...   2019-03-01
# 11                                Au Long de la Loire   2019-03-01
# 12                                     I Still Miss U   2019-03-15
# 13                                     Kolmekymppinen         1980
# 14                                              Bruja   2018-04-24
# 15                            Sonatas for two violins   2019-03-01
# 16                                            Sirènes   2019-03-01
# 17                                       Light of Day   2019-03-01
# 18                                   Madame del Campo   2015-08-03
# 19  Beethoven: Piano Concerto No. 2 & Triple Conce...   2019-03-01
# 20                                      Violinsonaten   2019-03-01

# %%
#cleaning the data
print(f"{album.info()}\n")
print(f"{artists.info()}\n")
print(f"{tracks.info()}\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75511 entries, 0 to 75510
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              75511 non-null  int64
#  1   album_type              75511 non-null  object
#  2   artist_id               75511 non-null  object
#  3   available_markets       75511 non-null  object
#  4   external_urls           75511 non-null  object
#  5   href                    75511 non-null  object
#  6   id                      75511 non-null  object
#  7   images                  75511 non-null  object
#  8   name                    75511 non-null  object
#  9   release_date            75511 non-null  object
#  10  release_date_precision  75511 non-null  object
#  11  total_tracks            75511 non-null  int64
#  12  track_id                75511 non-null  object
#  13  track_name_prev         75511 non-null  object
#  14  uri                     75511 non-null  object
#                    75511 non-null  object
# dtypes: int64(2), object(14)
# memory usage: 9.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56129 entries, 0 to 56128
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         56129 non-null  int64
#  1   artist_popularity  56129 non-null  int64
#  2   followers          56129 non-null  int64
#  3   genres             56129 non-null  object
#  4   id                 56129 non-null  object
#  5   name               56128 non-null  object
#  6   track_id           56129 non-null  object
#  7   track_name_prev    56129 non-null  object
#  8   type               56129 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 3.9+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101939 entries, 0 to 101938
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         101939 non-null  int64
#  1   acousticness       101939 non-null  float64
#  2   album_id           101939 non-null  object
#  3   analysis_url       101939 non-null  object
#  4   artists_id         101939 non-null  object
#  5   available_markets  101939 non-null  object
#  6   country            101939 non-null  object
#  7   danceability       101939 non-null  float64
#  8   disc_number        101939 non-null  float64
#  9   duration_ms        101939 non-null  float64
#  10  energy             101939 non-null  float64
#  11  href               101939 non-null  object
#  12  id                 101939 non-null  object
#  13  instrumentalness   101939 non-null  float64
#  14  key                101939 non-null  float64
#  15  liveness           101939 non-null  float64
#  16  loudness           101939 non-null  float64
#  17  lyrics             101939 non-null  object
#  18  mode               101939 non-null  float64
#  19  name               101939 non-null  object
#  20  playlist           101939 non-null  object
#  21  popularity         101939 non-null  float64
#  22  preview_url        101939 non-null  object
#  23  speechiness        101939 non-null  float64
#  24  tempo              101939 non-null  float64
#  25  time_signature     101939 non-null  float64
#  26  track_href         101939 non-null  object
#  27  track_name_prev    101939 non-null  object
#  28  track_number       101939 non-null  float64
#  29  uri                101939 non-null  object
#  30  valence            101939 non-null  float64
#  31  type               101939 non-null  object
# dtypes: float64(16), int64(1), object(15)
# memory usage: 24.9+ MB
# None

# %%
#columns in the album file deemed to have little litle decision making weight were: 'external urls', 'href', 'images', 'release_date_precision', and 'uri' thus were dropped. The 'available_markets' column was dropped because there was minimal use for this assignment.
drop_cols_album = ['external_urls', 'href', 'images', 'release_date_precision', 'uri', 'available_markets']
album.drop(drop_cols_album, inplace=True, axis=1)

#columns in the tracks file deemed to have little litle decision making weight were:
drop_cols_tracks = ['analysis_url', 'available_markets', 'uri', 'preview_url']
tracks.drop(drop_cols_tracks, inplace=True, axis=1)

#all columns in the artists data set were inconsequential thus were not dropped.

# %%
#rename the id column to be consistent with the other files
album = album.rename(columns={'id': 'album_id', 'name': 'song_name'})
tracks = tracks.rename(columns={'id': 'track_id', 'name': 'track_name'})
artists = artists.rename(columns={'id': 'artist_id', 'name': 'artist_name'})

#check for duplicate id's: no duplicates
duplicate_ids_album =album[album.duplicated(subset='album_id')]
duplicate_ids_track =tracks[tracks.duplicated(subset='track_id')]
duplicate_ids_artist =artists[artists.duplicated(subset='artist_id')]
print(f"duplicate ids:\n {duplicate_ids_album}")
print(f"duplicate ids:\n {duplicate_ids_track}")
print(f"duplicate ids:\n {duplicate_ids_artist}")
# Out:
# duplicate ids:
#  Empty DataFrame
# ]olumns: [Unnamed: 0, album_type, artist_id, album_id, song_name, release_date, total_tracks, track_id, track_name_prev, type
# Index: []
# duplicate ids:
#  Empty DataFrame
# Columns: [Unnamed: 0, acousticness, album_id, artists_id, country, danceability, disc_number, duration_ms, energy, href, track_id, instrumentalness, key, liveness, loudness, lyrics, mode, track_name, playlist, popularity, speechiness, tempo, time_signature, track_href, track_name_prev, track_number, valence, type]
# Index: []
#
# [0 rows x 28 columns]
# duplicate ids:
#  Empty DataFrame
# Columns: [Unnamed: 0, artist_popularity, followers, genres, artist_id, artist_name, track_id, track_name_prev, type]
# Index: []

# %%
#for artists, write a map() function to replace the empty list entries in the genre column with NaN's (but dont alter the lists that already have values)

def fill_genre(value):
  if value == '[]':
    return np.NaN
  else:
    return value
artists['genres'] = artists['genres'].map(fill_genre)
artists['genres'].unique()
# Out:
# array(["['sertanejo', 'sertanejo pop', 'sertanejo tradicional', 'sertanejo universitario']",
#        nan, "['danish pop rock']", ...,
#        "['dance pop', 'hip pop', 'pop', 'post-teen pop', 'r&b']",
#        "['chilean rock', 'concepcion indie']",
#        "['aggro chileno', 'andean', 'chilean rock', 'latin rock', 'nueva cancion']"],
#       dtype=object)

# %%
print(tracks['lyrics'].unique())
# Out:
# ["\r\n\r\nPerhaps I am bound to be restless\r\nAlways yearning, never satisfied\r\nPerhaps I'm aching for nothing\r\nThat words can't ever define\r\n\r\nWas I happy in those moments\r\nOr have I made it seem that way?\r\nWas I back there tomorrow\r\nCould feel as lacking as today?\r\n\r\nBut you in your golden hour\r\nAnd you with your sweetest song\r\nAnd you with your tender offerings\r\nHow could I ever do you wrong?\r\n\r\nThere's an unrest that keeps me marching\r\nThere's foolish hope that can be found\r\nSomething so true and lasting\r\nCould it land me on the ground?\r\nStill I like my world boundless\r\nIt never ceases to entice\r\nIt's the hunger in my bones\r\nIt's the new day in my eyes\r\n\r\nAnd you in your darkened hour\r\nAnd me and my broken soul\r\nHere you come with the tender offerings\r\nHow could I ever do you wrong?\r\n\r\nAnd me in my doubting hour\r\nAnd you with your soothing song\r\nAnd you when you call my mercy\r\nAnd you when you can't be strong\r\nHere you come with your tender offerings\r\nHow could I ever do you wrong?\r\nHow could I ever do you wrong?\r\nHow could I ever do you wrong?\r\n"
#  '\r\nYour Gods and my Gods-do you or I know which are the stronger? Native Proverb.\r\nEAST of Suez, some hold, the direct control of Providence ceases; Man being there handed over to the power of the Gods and Devils of Asia, and the Church of England Providence only exercising an occasional and modified supervision in the case of Englishmen.\r\nThis theory accounts for some of the more unnecessary horrors of life in India: it may be stretched to explain my story.\r\nMy friend Strickland of the Police, who knows as much of natives of India as is good for any man, can bear witness to the facts of the case. Dumoise, our doctor, also saw what Strickland and I saw. The inference which he drew from the evidence was entirely incorrect. He is dead now; he died, in a rather curious manner, which has been elsewhere described.\r\nWhen Fleete came to India he owned a little money and some land in the Himalayas, near a place called Dharmsala. Both properties had been left him by an uncle, and he came out to finance them. He was a big, heavy, genial, and inoffensive man. His knowledge of natives was, of course, limited, and he complained of the difficulties of the language.\r\nHe rode in from his place in the hills to spend New Year in the station, and he stayed with Strickland. On New Year\'s Eve there was a big dinner at the club, and the night was excusably wet. When men foregather from the uttermost ends of the Empire, they have a right to be riotous. The Frontier had sent down a contingent o\' Catch-\'em-Alive-O\'s who had not seen twenty white faces for a year, and were used to ride fifteen miles to dinner at the next Fort at the risk of a Khyberee bullet where their drinks should lie. They profited by their new security, for they tried to play pool with a curled-up hedgehog found in the garden, and one of them carried the marker round the room in his teeth. Half a dozen planters had come in from the south and were talking \'horse\' to the Biggest Liar in Asia, who was trying to cap all their stories at once. Everybody was there, and there was a general closing up of ranks and taking stock of our losses in dead or disabled that had fallen during the past year. It was a very wet night, and I remember that we sang \'Auld Lang Syne\' with our feet in the Polo Championship Cup, and our heads among the stars, and swore that we were all dear friends. Then some of us went away and annexed Burma, and some tried to open up the Soudan and were opened up by Fuzzies in that cruel scrub outside Suakim, and some found stars and medals, and some were married, which was bad, and some did other things which were worse, and the others of us stayed in our chains and strove to make money on insufficient experiences.\r\nFleete began the night with sherry and bitters, drank champagne steadily up to dessert, then raw, rasping Capri with all the strength of whisky, took Benedictine with his coffee, four or five whiskies and sodas to improve his pool strokes, beer and bones at half-past two, winding up with old brandy. Consequently, when he came out, at half-past three in the morning, into fourteen degrees of frost, he was very angry with his horse for coughing, and tried to leapfrog into the saddle. The horse broke away and went to his stables; so Strickland and I formed a Guard of Dishonour to take Fleete home.\r\nOur road lay through the bazaar, close to a little temple of Hanuman, the Monkey-god, who is a leading divinity worthy of respect. All gods have good points, just as have all priests. Personally, I attach much importance to Hanuman, and am kind to his people—the great gray apes of the hills. One never knows when one may want a friend.\r\nThere was a light in the temple, and as we passed, we could hear voices of men chanting hymns. In a native temple, the priests rise at all hours of the night to do honour to their god. Before we could stop him, Fleete dashed up the steps, patted two priests on the back, and was gravely grinding the ashes of his  ...
#  "\r\n\r\nClosed off from love, I didn't need the pain\r\nOnce or twice was enough and it was all in vain\r\nTime starts to pass, before you know it you're frozen\r\nBut something happened for the very first time with you\r\nMy heart melted to the ground\r\nFound something true\r\nAnd everyone's looking round thinking I'm going crazy\r\n\r\nBut I don't care what they say, I'm in love with you\r\nThey try to pull me away, but they don't know the truth\r\nMy heart's crippled by the vein that I keep on closing\r\nYou cut me open and I\r\n\r\nKeep bleeding\r\nKeep, keep bleeding love\r\nI keep bleeding\r\nI keep, keep bleeding love\r\nKeep bleeding\r\nKeep, keep bleeding love\r\nYou cut me open\r\n\r\nTrying hard not to hear, but they talk so loud\r\nTheir piercing sounds fill my ears, try to fill me with doubt\r\nYet I know that their goal is to keep me from falling\r\nBut nothing's greater than the risk\r\nThat comes with your embrace\r\nAnd in this world of loneliness, I see your face\r\nYet everyone around me thinks that I'm going crazy\r\nMaybe, maybe\r\n\r\nBut I don't care what they say, I'm in love with you\r\nThey try to pull me away, but they don't know the truth\r\nMy heart's crippled by the vein that I keep on closing\r\nYou cut me open and I\r\n\r\nKeep bleeding\r\nKeep, keep bleeding love\r\nI keep bleeding\r\nI keep, keep bleeding love\r\nKeep bleeding\r\nKeep, keep bleeding love\r\nYou cut me open\r\n\r\nAnd it's draining all of me\r\nThough they find it hard to believe\r\nI'll be wearing these scars for everyone to see\r\n\r\nBut I don't care what they say, I'm in love with you\r\nThey try to pull me away, but they don't know the truth\r\nMy heart's crippled by the vein that I keep on closing\r\nYou cut me open and I\r\n\r\nKeep bleeding\r\nKeep, keep bleeding love\r\nI keep bleeding\r\nI keep, keep bleeding love\r\nKeep bleeding\r\nKeep, keep bleeding love\r\n(Ooh, you cut me open and I)\r\nKeep bleeding\r\nKeep, keep bleeding love\r\nI keep bleeding\r\nI keep, keep bleeding love\r\nKeep bleeding\r\nKeep, keep bleeding love\r\n\r\nOoh, you cut me open and I\r\nKeep bleeding\r\nKeep, keep bleeding love\r\n"
#  ...
#  "\r\nNo more maybes\r\nYour baby's got rabies\r\nSitting on a ball\r\nIn the middle of the Andes\r\nYeah, I'm a freak of nature\r\nYeah, I'm a freak\r\nIf only I could be as cool as you\r\nAs cool as you\r\nBody and soul, I'm a freak I'm a freak\r\nBody and soul, I'm a freak I'm a freak\r\nTry to be different\r\nWell get a different disease\r\nSeems it's in fashion\r\nTo need the coldsore cream\r\nYeah, I'm a freak of nature\r\nYeah, I'm a freak\r\nI don't really know\r\nHow to put on a 'cool' show\r\nAs boring as they come\r\nJust tell me where to go\r\nIf only I could be as cool as you\r\nAs cool as you\r\nAs cool as you\r\nAs cool as you\r\nBody and soul, I'm a freak I'm a freak\r\nBody and soul, I'm a freak I'm a freak\r\nBody and soul, I'm a freak I'm a freak\r\nBody and soul, I'm a freak I'm a freak\r\nFreak\r\nFreak\r\nFreak\r\nFreak\r\n"
#  '\r\nWalking down the street\r\nWith some evil in my eye\r\nAnd some thoughts in my head\r\nThat were making me feel high\r\nOn my head was a hoodie\r\nIn my ears was some bass\r\nI was walking by my dog\r\nWhen I saw that sexy face\r\nCome towards me\r\nWith a little cheeky smile\r\nIf she was a phone\r\nI\'d pick her up and dial\r\nThe fire brigade\r\nOr zero zero zero\r\nShe stopped me in my tracks\r\nAnd I said, "Mmm hchello, hchello..."\r\nWoah hchello, hchello\r\nI was sleeping in the sand\r\nWith some dreams in my head\r\nThat were causing an extension\r\nTo the towel and my bed\r\nAnd the waves were a-rolling\r\nLike the curves on those legs\r\nOf the sweet beach bella\r\nWith that centerfold spread\r\nIn the midst of the slumber\r\nI heard some footsteps creeping\r\nAnd I woke to discover\r\nThe woman I\'d been dreaming\r\nShe knelt down beside\r\nSaid, "Can I share your pillow?"\r\nI rolled over and I said\r\n"Well hchello hchello..."\r\nOh hchello, hchello\r\nSome like money making\r\nSome like cars\r\nAnd some like the houses\r\nWith the rooftop spas\r\nAnd some like to gossip\r\nAbout some rich sugar daddies\r\nBut me and my friends\r\nWe like the golden brown honeys\r\nAnd some like watching people\r\nLiving on TV\r\nThat\'s a little strange\r\nIf you\'re asking me\r\nCause I like to eat and laugh\r\nAnd fuck and play down low\r\nThese are the things I know\r\nWell hchello, hchello\r\nOh, hchello hchello\r\nHchello, hchello\r\nOh, hchello hchello\r\nWelcome to this night\r\nWelcome to this song\r\nWelcome to these rhymes\r\nThat be going on and on\r\nWelcome to the empire\r\nAnd the funky empire tunes\r\nBut most of all welcome\r\nTo the bellas in this room\r\nWelcome to this night\r\nWelcome to this song\r\nWelcome to these rhymes\r\nThat be going on and on\r\nWelcome to the empire\r\nAnd the funky empire tunes\r\nBut most of all welcome\r\nTo the bellas in this room\r\nHchello, hchello\r\nWoah hchello, hchello\r\nWoah hchello, hchello\r\nPablo, Pablo\r\nWoah hchello, hchello\r\nOh hchello, hchello\r\nWell hchello, hchello\r\nOh hchello, hchello\r\nHello, hello\r\n'
#  "\r\nThere's not enough hours in my day\r\nTo tell you that you're getting in the way\r\nThere's not enough words in my book\r\nTo explain how I got over you\r\nI feel all cramped up now\r\nTrapped in this single bed\r\nConcrete thoughts of you\r\nWeighing down my head\r\nSleeping with my nemesis\r\nScattered on the quilt\r\nMy hand is always down my pants\r\nGuilt guilt guilt\r\nDo you think it's the right time\r\nWould it make it better\r\nDon't you think it's the worst time\r\nTo send you this plastic loveless letter \r\nThere's not enough hours in my day\r\nTo tell you that you're getting in the way\r\nThere's not enough words in my book\r\nTo explain how I got over you\r\nI want you so much more now\r\nI miss your bones like hell\r\nI wish you were beside me\r\n'Cos now I'm in better health\r\nI just have to say\r\nI just can't resist\r\nI just have to say\r\nI have to tell you this\r\nDo you think it's the right time\r\nWould it make it better\r\nDon't you think it's the worst time\r\nDon't you think its the best time\r\nDo you think it's the right time\r\nTo send you this plastic loveless letter \r\nA plastic loveless letter \r\nTo send you \r\nA plastic loveless letter \r\nTo send you \r\nA plastic loveless letter \r\n"]

# %%
tracks.drop(['lyrics'], inplace=True, axis=1)
print(tracks.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101939 entries, 0 to 101938
# Data columns (total 27 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        101939 non-null  int64
#  1   acousticness      101939 non-null  float64
#  2   album_id          101939 non-null  object
#  3   artists_id        101939 non-null  object
#  4   country           101939 non-null  object
#  5   danceability      101939 non-null  float64
#  6   disc_number       101939 non-null  float64
#  7   duration_ms       101939 non-null  float64
#  8   energy            101939 non-null  float64
#  9   href              101939 non-null  object
#  10  track_id          101939 non-null  object
#  11  instrumentalness  101939 non-null  float64
#  12  key               101939 non-null  float64
#  13  liveness          101939 non-null  float64
#  14  loudness          101939 non-null  float64
#  15  mode              101939 non-null  float64
#  16  track_name        101939 non-null  object
#  17  playlist          101939 non-null  object
#  18  popularity        101939 non-null  float64
#  19  speechiness       101939 non-null  float64
#  20  tempo             101939 non-null  float64
#  21  time_signature    101939 non-null  float64
#  22  track_href        101939 non-null  object
#  23  track_name_prev   101939 non-null  object
#  24  track_number      101939 non-null  float64
#  25  valence           101939 non-null  float64
#  26  type              101939 non-null  object
# dtypes: float64(16), int64(1), object(10)
# memory usage: 21.0+ MB
# None

# %%
#Join artists and albums on the artist ID

artists_with_albums = pd.merge(artists, album, on='artist_id', how='outer')
print(artists_with_albums.shape)
print(artists_with_albums.head())

#join albums and tracks on the album_ID
albums_with_tracks = pd.merge(album, tracks, on='album_id', how='outer')
print(albums_with_tracks.shape)
albums_with_tracks.head()

print(albums_with_tracks.info())
artists_with_albums.head()
# Out:
# (93039, 18)
#    Unnamed: 0_x  artist_popularity  followers  \
# 0           0.0               44.0    23230.0
# 1           0.0               44.0    23230.0
# 2           1.0               22.0      313.0
# 3           2.0               26.0     1596.0
# 4           3.0               31.0      149.0
#
#                                               genres               artist_id  \
# 0  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 1  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 2                                                NaN  1dLnVku4VQUOLswwDFvRc9
# 3                                ['danish pop rock']  6YVY310fjfUzKi8hiqR7iK
# 4                             ['uk alternative pop']  2VElyouiCfoYPDJluzwJwK
#
#       artist_name              track_id_x track_name_prev_x    type  \
# 0   Juliano Cezar  0wmDmAILuW9e2aRttkl4aC           track_9  artist
# 1   Juliano Cezar  0wmDmAILuW9e2aRttkl4aC           track_9  artist
# 2  The Grenadines  4wqwj0gA8qPZKLl5WVqXml          track_30  artist
# 3         Gangway  1bFqWDbvHmZe2f4Nf9qaD8          track_38  artist
# 4           FADES  3MFSUBAidPzRBbIS7BDj1S          track_34  artist
#
#    Unnamed: 0_y album_type                album_id                  song_name  \
# 0          50.0      album  2tx2zEr2JUKhDqnRlWQdzR   É Isso Que A Galera Quer
# 1        4798.0      album  2zmd7Bn7in6CrgdHpFvU0b  Sucessos de Juliano Cézar
# 2        3680.0      album  5YEORJnaovJcPqKNhlIQlx          Band on the Radio
# 3         157.0      album  65CsTqUbM5RH0jFRZdIygK           Happy Ever After
# 4        4779.0     single  7Jbgxp7IqL09ODxOPYJJkv                     Wasted
#
#   release_date  total_tracks              track_id_y track_name_prev_y  \
# 0   2006-09-01          15.0  5CJ8U9o3Ke5wmUEt37hBGQ          track_19
# 1   2013-08-01          15.0  0wmDmAILuW9e2aRttkl4aC          track_14
# 2   2018-11-16          10.0  4wqwj0gA8qPZKLl5WVqXml          track_28
# 3   1992-09-17          12.0  1bFqWDbvHmZe2f4Nf9qaD8          track_36
# 4   2019-02-22           1.0  3MFSUBAidPzRBbIS7BDj1S          track_37
#
#     type\r
# 0  album\r
# 1  album\r
# 2  album\r
# 3  album\r
# 4  album\r
# (101947, 36)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101947 entries, 0 to 101946
# Data columns (total 36 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0_x       101947 non-null  int64
#  1   album_type         101947 non-null  object
#  2   artist_id          101947 non-null  object
#  3   album_id           101947 non-null  object
#  4   song_name          101947 non-null  object
#  5   release_date       101947 non-null  object
#  6   total_tracks       101947 non-null  int64
#  7   track_id_x         101947 non-null  object
#  8   track_name_prev_x  101947 non-null  object
#               101947 non-null  object
#  10  Unnamed: 0_y       101939 non-null  float64
#  11  acousticness       101939 non-null  float64
#  12  artists_id         101939 non-null  object
#  13  country            101939 non-null  object
#  14  danceability       101939 non-null  float64
#  15  disc_number        101939 non-null  float64
#  16  duration_ms        101939 non-null  float64
#  17  energy             101939 non-null  float64
#  18  href               101939 non-null  object
#  19  track_id_y         101939 non-null  object
#  20  instrumentalness   101939 non-null  float64
#  21  key                101939 non-null  float64
#  22  liveness           101939 non-null  float64
#  23  loudness           101939 non-null  float64
#  24  mode               101939 non-null  float64
#  25  track_name         101939 non-null  object
#  26  playlist           101939 non-null  object
#  27  popularity         101939 non-null  float64
#  28  speechiness        101939 non-null  float64
#  29  tempo              101939 non-null  float64
#  30  time_signature     101939 non-null  float64
#  31  track_href         101939 non-null  object
#  32  track_name_prev_y  101939 non-null  object
#  33  track_number       101939 non-null  float64
#  34  valence            101939 non-null  float64
#  35  type               101939 non-null  object
# dtypes: float64(17), int64(2), object(17)
# memory usage: 28.8+ MB
# None
#    Unnamed: 0_x  artist_popularity  followers  \
# 0           0.0               44.0    23230.0
# 1           0.0               44.0    23230.0
# 2           1.0               22.0      313.0
# 3           2.0               26.0     1596.0
# 4           3.0               31.0      149.0
#
#                                               genres               artist_id  \
# 0  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 1  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 2                                                NaN  1dLnVku4VQUOLswwDFvRc9
# 3                                ['danish pop rock']  6YVY310fjfUzKi8hiqR7iK
# 4                             ['uk alternative pop']  2VElyouiCfoYPDJluzwJwK
#
#       artist_name              track_id_x track_name_prev_x    type  \
# 0   Juliano Cezar  0wmDmAILuW9e2aRttkl4aC           track_9  artist
# 1   Juliano Cezar  0wmDmAILuW9e2aRttkl4aC           track_9  artist
# 2  The Grenadines  4wqwj0gA8qPZKLl5WVqXml          track_30  artist
# 3         Gangway  1bFqWDbvHmZe2f4Nf9qaD8          track_38  artist
# 4           FADES  3MFSUBAidPzRBbIS7BDj1S          track_34  artist
#
#    Unnamed: 0_y album_type                album_id                  song_name  \
# 0          50.0      album  2tx2zEr2JUKhDqnRlWQdzR   É Isso Que A Galera Quer
# 1        4798.0      album  2zmd7Bn7in6CrgdHpFvU0b  Sucessos de Juliano Cézar
# 2        3680.0      album  5YEORJnaovJcPqKNhlIQlx          Band on the Radio
# 3         157.0      album  65CsTqUbM5RH0jFRZdIygK           Happy Ever After
# 4        4779.0     single  7Jbgxp7IqL09ODxOPYJJkv                     Wasted
#
#   release_date  total_tracks              track_id_y track_name_prev_y  \
# 0   2006-09-01          15.0  5CJ8U9o3Ke5wmUEt37hBGQ          track_19
# 1   2013-08-01          15.0  0wmDmAILuW9e2aRttkl4aC          track_14
# 2   2018-11-16          10.0  4wqwj0gA8qPZKLl5WVqXml          track_28
# 3   1992-09-17          12.0  1bFqWDbvHmZe2f4Nf9qaD8          track_36
# 4   2019-02-22           1.0  3MFSUBAidPzRBbIS7BDj1S          track_37
#
#     type\r
# 0  album\r
# 1  album\r
# 2  album\r
# 3  album\r
# 4  album\r

# %%
#Which artists appear the most times in the Artists data?
print(artists[['artist_name']].value_counts(ascending=False)) #Haze appears the most, with 5 appearances

#Which artists have the highest 'artist_popularity' rankings? (list the top ten in descending order)
# artists.drop_duplicates(subset='artist_name', inplace=True)
# artists[['artist_popularity', 'artist_name']].sort_values(by='artist_popularity', ascending=False).head(10)
artists_with_albums.drop_duplicates(subset='artist_name', inplace=True)
artists_with_albums[['artist_popularity', 'artist_name']].sort_values(by='artist_popularity', ascending=False).head(10)
# Out:
# artist_name
# Haze                             5
# Sasha                            5
# Luna                             4
# Alex                             4
# Plan B                           4
#                                 ..
# Gollo                            1
# Goloise                          1
# Golosinomano                     1
# Golpa (Ali Akbar Golpayegani)    1
# 홍크 Honk                          1
# Length: 55505, dtype: int64
#        artist_popularity    artist_name
# 56596              100.0  Ariana Grande
# 83660               98.0          Drake
# 71462               96.0    Post Malone
# 91381               95.0   XXXTENTACION
# 78004               95.0          Ozuna
# 83718               95.0         Khalid
# 71229               95.0     Juice WRLD
# 49865               94.0          Queen
# 70197               94.0   Travis Scott
# 77923               94.0       Anuel Aa

# %%
#how many albums came out in each year?
album['year'] = pd.DatetimeIndex(album['release_date']).year
print(album[['year']].value_counts())
# Out:
# year
# 2018    22050
# 2019    11125
# 2017     9231
# 2016     5111
# 2015     3229
#         ...
# 1938        1
# 1939        1
# 1942        1
# 1948        1
# 1886        1
# Length: 88, dtype: int64
